# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=3
b=0.5

x_lin = np.linspace(0,100,101)

y= (x_lin + np.random.randn(101) * 5 ) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we heave data points")
plt.legend(loc=2)
plt.show()

# %%
y_hat = x_lin * w +b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-',label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc=2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    # MAE : 將兩個陣列相減後, 取絕對值(abs), 再將整個陣列加總成一個數字(sum), 最後除以y的長度(len), 因此稱為"平均絕對誤差"
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 呼叫上述函式, 傳回 y(藍點高度)與 y_hat(紅線高度) 的 MAE
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.427

# %%
def mean_square_error(y, yp):
    mse = MSE = sum(abs(y - yp)**2) / len(y)
    return mse

MSE = mean_square_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 237.826

# %% [markdown]
# 作業2：
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要?
#
# 我選的這組資料是Blood Cell Images（血細胞），因為大部分的人都會有血細胞，所以對於判斷RBC (Red Blood Cell)，WBC (White Blood Cell) 和 Platelets (血小板)的準確性及便利性是極其重要的。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)?
#
# 這組資料從一個github user 叫shenggan所提供。
#
# 3. 蒐集而來的資料型態為何?
#
# 結構化資料的csv檔。
#
# 4. 這組資料想解決的問題如何評估?
#
# 分類血細胞和準確度。

# %% [markdown]
# 作業3：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 對我而言，核心問題應該是車隊分配不均。如果A地方客人流動量大，那A地方就需要比較多的車隊。加上時間軸可以幫助哪個時間是高峰，並在低峰的時候可以讓其他車隊到B地方協助。也可以把慶典/假日考慮進去。
#
# 另外，可以利用多數人使用路線收集資料，然後進行一個假設。假設規劃一個promotion 給常行駛路線的客人優惠，那是不是會口口相傳？迎來更多的商機或與公司合作之類的。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 經由接單資料的多寡決定車隊分配。
# 經由GPS路線以每單決定promotion。
#
# 3. 蒐集而來的資料型態為何
#
# 結構性資料
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# 檢視不同區域的載客數或載客行駛公里數，藉此改變執行策略來達到提升載客數量，並以此達到提升業績的目的。
